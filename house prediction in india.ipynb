# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
train = pd.read_csv("C:\\Users\\ABC\\Desktop\\train.csv")
test = df = pd.read_csv("C:\\Users\\ABC\\Desktop\\test.csv")

# %%
train.shape,test.shape
# Out:
# ((29451, 12), (68720, 11))

# %%
train.head()
# Out:
#   POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0     Owner                   0     0        2       BHK  1300.236407
# 1    Dealer                   0     0        2       BHK  1275.000000
# 2     Owner                   0     0        2       BHK   933.159722
# 3     Owner                   0     1        2       BHK   929.921143
# 4    Dealer                   1     0        2       BHK   999.009247
#
#    READY_TO_MOVE  RESALE                      ADDRESS  LONGITUDE   LATITUDE  \
# 0              1       1        Ksfc Layout,Bangalore  12.969910  77.597960
# 1              1       1    Vishweshwara Nagar,Mysore  12.274538  76.644605
# 2              1       1             Jigani,Bangalore  12.778033  77.632191
# 3              1       1  Sector-1 Vaishali,Ghaziabad  28.642300  77.344500
# 4              0       1             New Town,Kolkata  22.592200  88.484911
#
#    TARGET(PRICE_IN_LACS)
# 0                   55.0
# 1                   51.0
# ...

# %%
test.head()
# Out:
#   POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0     Owner                   0     0        1       BHK   545.171340
# 1    Dealer                   1     1        2       BHK   800.000000
# 2    Dealer                   0     0        2       BHK  1257.096513
# 3    Dealer                   0     0        3       BHK  1400.329489
# 4     Owner                   0     0        1       BHK   430.477830
#
#    READY_TO_MOVE  RESALE             ADDRESS  LONGITUDE   LATITUDE
# 0              1       1        Kamrej,Surat  21.262000  73.047700
# 1              0       0     Panvel,Lalitpur  18.966114  73.148278
# 2              1       1    New Town,Kolkata  22.592200  88.484911
# 3              1       1  Kalwar Road,Jaipur  26.988300  75.584600
# 4              1       1   Mai Mandir,Nadiad  22.700000  72.870000

# %%
train.dtypes
# Out:
# POSTED_BY                 object
# UNDER_CONSTRUCTION         int64
# RERA                       int64
# BHK_NO.                    int64
# BHK_OR_RK                 object
# SQUARE_FT                float64
# READY_TO_MOVE              int64
# RESALE                     int64
# ADDRESS                   object
# LONGITUDE                float64
# LATITUDE                 float64
# TARGET(PRICE_IN_LACS)    float64
# dtype: object

# %%
train.isnull().sum()
# Out:
# POSTED_BY                0
# UNDER_CONSTRUCTION       0
# RERA                     0
# BHK_NO.                  0
# BHK_OR_RK                0
# SQUARE_FT                0
# READY_TO_MOVE            0
# RESALE                   0
# ADDRESS                  0
# LONGITUDE                0
# LATITUDE                 0
# TARGET(PRICE_IN_LACS)    0
# dtype: int64

# %%
sns.heatmap(train.corr())

# %%
train.corr()
# Out:
#                        UNDER_CONSTRUCTION      RERA   BHK_NO.  SQUARE_FT  \
# UNDER_CONSTRUCTION               1.000000  0.363826 -0.040712  -0.004204
# RERA                             0.363826  1.000000  0.009547  -0.006229
# BHK_NO.                         -0.040712  0.009547  1.000000   0.005303
# SQUARE_FT                       -0.004204 -0.006229  0.005303   1.000000
# READY_TO_MOVE                   -1.000000 -0.363826  0.040712   0.004204
# RESALE                          -0.347405 -0.270351  0.014581   0.001732
# LONGITUDE                        0.006440  0.104976  0.068730  -0.012591
# LATITUDE                        -0.000381 -0.065106  0.046930   0.000803
# TARGET(PRICE_IN_LACS)            0.055399  0.067636  0.112283   0.402685
#
#                        READY_TO_MOVE    RESALE  LONGITUDE  LATITUDE  \
# UNDER_CONSTRUCTION         -1.000000 -0.347405   0.006440 -0.000381
# RERA                       -0.363826 -0.270351   0.104976 -0.065106
# ...

# %%
train.describe()
# Out:
#        UNDER_CONSTRUCTION          RERA       BHK_NO.     SQUARE_FT  \
# count        29451.000000  29451.000000  29451.000000  2.945100e+04
# mean             0.179756      0.317918      2.392279  1.980217e+04
# std              0.383991      0.465675      0.879091  1.901335e+06
# min              0.000000      0.000000      1.000000  3.000000e+00
# 25%              0.000000      0.000000      2.000000  9.000211e+02
# 50%              0.000000      0.000000      2.000000  1.175057e+03
# 75%              0.000000      1.000000      3.000000  1.550688e+03
# max              1.000000      1.000000     20.000000  2.545455e+08
#
#        READY_TO_MOVE        RESALE     LONGITUDE      LATITUDE  \
# count   29451.000000  29451.000000  29451.000000  29451.000000
# mean        0.820244      0.929578     21.300255     76.837695
# std         0.383991      0.255861      6.205306     10.557747
# min         0.000000      0.000000    -37.713008   -121.761248
# ...

# %%
plt.hist("TARGET(PRICE_IN_LACS)",data = train)
# Out:
# (array([2.93e+04, 1.60e+01, 7.40e+01, 5.80e+01, 0.00e+00, 0.00e+00,
#         0.00e+00, 0.00e+00, 1.00e+00, 2.00e+00]),
#  array([2.5000000e-01, 3.0002250e+03, 6.0002000e+03, 9.0001750e+03,
#         1.2000150e+04, 1.5000125e+04, 1.8000100e+04, 2.1000075e+04,
#         2.4000050e+04, 2.7000025e+04, 3.0000000e+04]),
#  <a list of 10 Patch objects>)

# %%
del train['POSTED_BY']

# %%
del train["BHK_OR_RK"]

# %%
del train['ADDRESS']

# %%
x = train.iloc[:,:-1]
y = train.iloc[:,:1]

# %%
train.columns
# Out:
# Index(['UNDER_CONSTRUCTION', 'RERA', 'BHK_NO.', 'SQUARE_FT', 'READY_TO_MOVE',
#        'RESALE', 'LONGITUDE', 'LATITUDE', 'TARGET(PRICE_IN_LACS)'],
#       dtype='object')

# %%
train.dtypes
# Out:
# UNDER_CONSTRUCTION         int64
# RERA                       int64
# BHK_NO.                    int64
# SQUARE_FT                float64
# READY_TO_MOVE              int64
# RESALE                     int64
# LONGITUDE                float64
# LATITUDE                 float64
# TARGET(PRICE_IN_LACS)    float64
# dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((22088, 8), (7363, 8), (22088, 1), (7363, 1))

# %%
from sklearn.linear_model import LinearRegression as LR
lr = LR()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predict = lr.predict(x_test)

# %%
predict
# Out:
# array([[-4.85167462e-14],
#        [-7.28306304e-14],
#        [ 1.00000000e+00],
#        ...,
#        [-4.81836793e-14],
#        [ 1.00000000e+00],
#        [-7.52731211e-14]])

# %%
from sklearn.metrics import accuracy_score
lr.score(x_test,y_test)
# Out:
# 1.0

# %%
from sklearn.ensemble import RandomForestClassifier as RFC
rfc = RFC(max_depth=2,random_state = 45)
rfc.fit(x_train,y_train)
# Out:
# <ipython-input-109-1d6534e460dc>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfc.fit(x_train,y_train)
# RandomForestClassifier(max_depth=2, random_state=45)

# %%
predict = rfc.predict(x_test)

# %%
predict
# Out:
# array([0, 0, 1, ..., 0, 1, 0], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix
print("confusion _matrix\n"+str(confusion_matrix(y_test,predict)))
# Out:
# confusion _matrix
# [[6050    0]
#  [   0 1313]]

# %%
sns.pairplot(data= train)

# %%
df.hist(figsize=(10,10),edgecolor="k")
plt.tight_layout()
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
ag = AgglomerativeClustering(n_clusters=3,affinity="euclidean",linkage = "ward")

# %%
ag
# Out:
# AgglomerativeClustering(n_clusters=3)

# %%
ag.fit_predict(train)
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
plt.figure(figsize=(4,8))
plt.scatter(train['SQUARE_FT'],train['TARGET(PRICE_IN_LACS)'])
